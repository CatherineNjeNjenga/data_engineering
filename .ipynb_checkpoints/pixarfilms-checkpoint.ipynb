# %%
import duckdb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import duckdb
#
# ModuleNotFoundError: No module named 'duckdb'

# %%
pip install duckdb
# Out:
# Collecting duckdb
#   Downloading duckdb-1.3.2-cp313-cp313-win_amd64.whl.metadata (7.2 kB)
# Downloading duckdb-1.3.2-cp313-cp313-win_amd64.whl (11.4 MB)
#    ---------------------------------------- 0.0/11.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.4 MB 1.2 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.6/11.4 MB 1.9 MB/s eta 0:00:06
#    ------- -------------------------------- 2.1/11.4 MB 2.1 MB/s eta 0:00:05
#    --------- ------------------------------ 2.6/11.4 MB 2.1 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.9/11.4 MB 2.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.1/11.4 MB 1.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.1/11.4 MB 1.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.1/11.4 MB 1.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.1/11.4 MB 1.9 MB/s eta 0:00:05
#    ----------- ---------------------------- 3.4/11.4 MB 1.3 MB/s eta 0:00:07
#    ------------- -------------------------- 3.9/11.4 MB 1.4 MB/s eta 0:00:06
#    -------------- ------------------------- 4.2/11.4 MB 1.4 MB/s eta 0:00:05
#    ----------------- ---------------------- 5.0/11.4 MB 1.6 MB/s eta 0:00:05
#    ------------------ --------------------- 5.2/11.4 MB 1.6 MB/s eta 0:00:04
#    ------------------- -------------------- 5.5/11.4 MB 1.6 MB/s eta 0:00:04
#    ---------------------- ----------------- 6.3/11.4 MB 1.6 MB/s eta 0:00:04
#    ----------------------- ---------------- 6.8/11.4 MB 1.7 MB/s eta 0:00:03
#    ------------------------ --------------- 7.1/11.4 MB 1.7 MB/s eta 0:00:03
#    -------------------------- ------------- 7.6/11.4 MB 1.7 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.4/11.4 MB 1.8 MB/s eta 0:00:02
#    ------------------------------- -------- 8.9/11.4 MB 1.8 MB/s eta 0:00:02
#    --------------------------------- ------ 9.4/11.4 MB 1.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 10.2/11.4 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.4 MB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.4 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.4 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.4 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.4 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.4 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.4/11.4 MB 1.7 MB/s eta 0:00:00
# Installing collected packages: duckdb
# Successfully installed duckdb-1.3.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import duckdb

# %%
pixar_films = pandas.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-03-11/pixar_films.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pixar_films = pandas.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-03-11/pixar_films.csv')
#
# NameError: name 'pandas' is not defined

# %%
pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.10.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# attrs                     25.3.0
# babel                     2.17.0
# beautifulsoup4            4.13.4
# bleach                    6.2.0
# certifi                   2025.8.3
# cffi                      1.17.1
# charset-normalizer        3.4.3
# colorama                  0.4.6
# comm                      0.2.3
# debugpy                   1.8.16
# decorator                 5.2.1
# defusedxml                0.7.1
# duckdb                    1.3.2
# executing                 2.2.0
# fastjsonschema            2.21.2
# fqdn                      1.5.1
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.10
# ipykernel                 6.30.1
# ipython                   9.4.0
# ipython_pygments_lexers   1.1.1
# isoduration               20.11.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# json5                     0.12.1
# jsonpointer               3.0.0
# jsonschema                4.25.0
# jsonschema-specifications 2025.4.1
# jupyter_client            8.6.3
# jupyter_core              5.8.1
# jupyter-events            0.12.0
# jupyter-lsp               2.2.6
# jupyter_server            2.16.0
# jupyter_server_terminals  0.5.3
# jupyterlab                4.4.5
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.3
# lark                      1.2.2
# MarkupSafe                3.0.2
# matplotlib-inline         0.1.7
# mistune                   3.1.3
# nbclient                  0.10.2
# nbconvert                 7.16.6
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.4.5
# notebook_shim             0.2.4
# overrides                 7.7.0
# packaging                 25.0
# pandocfilters             1.5.1
# parso                     0.8.4
# pip                       24.3.1
# platformdirs              4.3.8
# prometheus_client         0.22.1
# prompt_toolkit            3.0.51
# psutil                    7.0.0
# pure_eval                 0.2.3
# pycparser                 2.22
# Pygments                  2.19.2
# python-dateutil           2.9.0.post0
# python-json-logger        3.3.0
# pywin32                   311
# pywinpty                  3.0.0
# PyYAML                    6.0.2
# pyzmq                     27.0.1
# referencing               0.36.2
# requests                  2.32.4
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rpds-py                   0.27.0
# Send2Trash                1.8.3
# setuptools                80.9.0
# six                       1.17.0
# sniffio                   1.3.1
# soupsieve                 2.7
# stack-data                0.6.3
# terminado                 0.18.1
# tinycss2                  1.4.0
# tornado                   6.5.2
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20250809
# typing_extensions         4.14.1
# uri-template              1.3.0
# urllib3                   2.5.0
# wcwidth                   0.2.13
# webcolors                 24.11.1
# webencodings              0.5.1
# websocket-client          1.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.3.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\toshiba\desktop\drawdaily\env\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\toshiba\desktop\drawdaily\env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.1-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 1.8 MB/s eta 0:00:06
#    --- ------------------------------------ 1.0/11.0 MB 1.8 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.6/11.0 MB 1.8 MB/s eta 0:00:06
#    ------ --------------------------------- 1.8/11.0 MB 1.9 MB/s eta 0:00:05
#    ------- -------------------------------- 2.1/11.0 MB 1.7 MB/s eta 0:00:06
#    -------- ------------------------------- 2.4/11.0 MB 1.5 MB/s eta 0:00:06
#    -------- ------------------------------- 2.4/11.0 MB 1.5 MB/s eta 0:00:06
#    -------- ------------------------------- 2.4/11.0 MB 1.5 MB/s eta 0:00:06
#    -------- ------------------------------- 2.4/11.0 MB 1.5 MB/s eta 0:00:06
#    ------------ --------------------------- 3.4/11.0 MB 1.4 MB/s eta 0:00:06
#    ------------- -------------------------- 3.7/11.0 MB 1.5 MB/s eta 0:00:05
#    -------------- ------------------------- 3.9/11.0 MB 1.5 MB/s eta 0:00:05
#    --------------- ------------------------ 4.2/11.0 MB 1.4 MB/s eta 0:00:05
#    ---------------- ----------------------- 4.5/11.0 MB 1.4 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.7/11.0 MB 1.3 MB/s eta 0:00:05
#    ------------------ --------------------- 5.0/11.0 MB 1.3 MB/s eta 0:00:05
#    ------------------- -------------------- 5.2/11.0 MB 1.3 MB/s eta 0:00:05
#    ------------------- -------------------- 5.2/11.0 MB 1.3 MB/s eta 0:00:05
#    -------------------- ------------------- 5.5/11.0 MB 1.3 MB/s eta 0:00:05
#    -------------------- ------------------- 5.8/11.0 MB 1.3 MB/s eta 0:00:04
#    -------------------- ------------------- 5.8/11.0 MB 1.3 MB/s eta 0:00:04
#    -------------------- ------------------- 5.8/11.0 MB 1.3 MB/s eta 0:00:04
#    ------------------------ --------------- 6.8/11.0 MB 1.3 MB/s eta 0:00:04
#    ------------------------- -------------- 7.1/11.0 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 7.3/11.0 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 7.6/11.0 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 7.9/11.0 MB 1.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.1/11.0 MB 1.3 MB/s eta 0:00:03
#    ------------------------------ --------- 8.4/11.0 MB 1.3 MB/s eta 0:00:02
#    ------------------------------ --------- 8.4/11.0 MB 1.3 MB/s eta 0:00:02
#    ------------------------------ --------- 8.4/11.0 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 9.4/11.0 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------ --- 10.0/11.0 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 10.2/11.0 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 10.2/11.0 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 10.5/11.0 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.5/11.0 MB 1.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.5/11.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 863.6 kB/s eta 0:00:00
# Downloading numpy-2.3.2-cp313-cp313-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.8 MB 46.2 MB/s eta 0:00:01
#    --- ------------------------------------ 1.0/12.8 MB 3.1 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.6/12.8 MB 2.6 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.8/12.8 MB 2.4 MB/s eta 0:00:05
#    ------- -------------------------------- 2.4/12.8 MB 2.2 MB/s eta 0:00:05
#    -------- ------------------------------- 2.6/12.8 MB 2.2 MB/s eta 0:00:05
#    --------- ------------------------------ 2.9/12.8 MB 2.1 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.4/12.8 MB 2.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.4/12.8 MB 2.0 MB/s eta 0:00:05
#    ------------ --------------------------- 3.9/12.8 MB 1.8 MB/s eta 0:00:05
#    ------------- -------------------------- 4.2/12.8 MB 1.8 MB/s eta 0:00:05
#    ------------- -------------------------- 4.5/12.8 MB 1.8 MB/s eta 0:00:05
#    --------------- ------------------------ 5.0/12.8 MB 1.8 MB/s eta 0:00:05
#    ---------------- ----------------------- 5.2/12.8 MB 1.7 MB/s eta 0:00:05
#    ---------------- ----------------------- 5.2/12.8 MB 1.7 MB/s eta 0:00:05
#    ------------------ --------------------- 5.8/12.8 MB 1.7 MB/s eta 0:00:05
#    ------------------ --------------------- 6.0/12.8 MB 1.7 MB/s eta 0:00:05
#    -------------------- ------------------- 6.6/12.8 MB 1.7 MB/s eta 0:00:04
#    --------------------- ------------------ 6.8/12.8 MB 1.7 MB/s eta 0:00:04
#    ---------------------- ----------------- 7.3/12.8 MB 1.7 MB/s eta 0:00:04
#    ----------------------- ---------------- 7.6/12.8 MB 1.7 MB/s eta 0:00:04
#    ------------------------ --------------- 7.9/12.8 MB 1.7 MB/s eta 0:00:03
#    -------------------------- ------------- 8.4/12.8 MB 1.7 MB/s eta 0:00:03
#    --------------------------- ------------ 8.7/12.8 MB 1.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 9.2/12.8 MB 1.7 MB/s eta 0:00:03
#    ------------------------------ --------- 9.7/12.8 MB 1.7 MB/s eta 0:00:02
#    ------------------------------- -------- 10.2/12.8 MB 1.8 MB/s eta 0:00:02
#    -------------------------------- ------- 10.5/12.8 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.0/12.8 MB 1.8 MB/s eta 0:00:02
#    -------------------------------------- - 12.3/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 987.2 kB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.3.2 pandas-2.3.1 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.10.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# attrs                     25.3.0
# babel                     2.17.0
# beautifulsoup4            4.13.4
# bleach                    6.2.0
# certifi                   2025.8.3
# cffi                      1.17.1
# charset-normalizer        3.4.3
# colorama                  0.4.6
# comm                      0.2.3
# debugpy                   1.8.16
# decorator                 5.2.1
# defusedxml                0.7.1
# duckdb                    1.3.2
# executing                 2.2.0
# fastjsonschema            2.21.2
# fqdn                      1.5.1
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.10
# ipykernel                 6.30.1
# ipython                   9.4.0
# ipython_pygments_lexers   1.1.1
# isoduration               20.11.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# json5                     0.12.1
# jsonpointer               3.0.0
# jsonschema                4.25.0
# jsonschema-specifications 2025.4.1
# jupyter_client            8.6.3
# jupyter_core              5.8.1
# jupyter-events            0.12.0
# jupyter-lsp               2.2.6
# jupyter_server            2.16.0
# jupyter_server_terminals  0.5.3
# jupyterlab                4.4.5
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.3
# lark                      1.2.2
# MarkupSafe                3.0.2
# matplotlib-inline         0.1.7
# mistune                   3.1.3
# nbclient                  0.10.2
# nbconvert                 7.16.6
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.4.5
# notebook_shim             0.2.4
# numpy                     2.3.2
# overrides                 7.7.0
# packaging                 25.0
# pandas                    2.3.1
# pandocfilters             1.5.1
# parso                     0.8.4
# pip                       24.3.1
# platformdirs              4.3.8
# prometheus_client         0.22.1
# prompt_toolkit            3.0.51
# psutil                    7.0.0
# pure_eval                 0.2.3
# pycparser                 2.22
# Pygments                  2.19.2
# python-dateutil           2.9.0.post0
# python-json-logger        3.3.0
# pytz                      2025.2
# pywin32                   311
# pywinpty                  3.0.0
# PyYAML                    6.0.2
# pyzmq                     27.0.1
# referencing               0.36.2
# requests                  2.32.4
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rpds-py                   0.27.0
# Send2Trash                1.8.3
# setuptools                80.9.0
# six                       1.17.0
# sniffio                   1.3.1
# soupsieve                 2.7
# stack-data                0.6.3
# terminado                 0.18.1
# tinycss2                  1.4.0
# tornado                   6.5.2
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20250809
# typing_extensions         4.14.1
# tzdata                    2025.2
# uri-template              1.3.0
# urllib3                   2.5.0
# wcwidth                   0.2.13
# webcolors                 24.11.1
# webencodings              0.5.1
# websocket-client          1.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pixar_films = pandas.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-03-11/pixar_films.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pixar_films = pandas.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-03-11/pixar_films.csv')
#
# NameError: name 'pandas' is not defined

# %%
import pandas

# %%
pixar_films = pandas.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-03-11/pixar_films.csv')

# %%
public_response = pandas.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-03-11/public_response.csv')

# %%
cn = duckdb.connect("pixar_films_data.db")

# %%
cn.execute("""
            INSTALL https;
            LOAD https;
            INSTALL excel;
            LOAD excel;
            """)

# %%
pixar_films
# Out:
#     number                 film release_date  run_time film_rating
# 0        1            Toy Story   1995-11-22      81.0           G
# 1        2         A Bug's Life   1998-11-25      95.0           G
# 2        3          Toy Story 2   1999-11-24      92.0           G
# 3        4       Monsters, Inc.   2001-11-02      92.0           G
# 4        5         Finding Nemo   2003-05-30     100.0           G
# 5        6      The Incredibles   2004-11-05     115.0          PG
# 6        7                 Cars   2006-06-09     117.0           G
# 7        8          Ratatouille   2007-06-29     111.0           G
# 8        9               WALL-E   2008-06-27      98.0           G
# 9       10                   Up   2009-05-29      96.0          PG
# 10      11          Toy Story 3   2010-06-18     103.0           G
# 11      12               Cars 2   2011-06-24     106.0           G
# 12      13                Brave   2012-06-22      93.0          PG
# 13      14  Monsters University   2013-06-21     104.0           G
# 14      15           Inside Out   2015-06-19      95.0          PG
# 15      16    The Good Dinosaur   2015-11-25      93.0          PG
# 16      17         Finding Dory   2016-06-17      97.0          PG
# 17      18               Cars 3   2017-06-16     102.0           G
# 18      19                 Coco   2017-11-22     105.0          PG
# 19      20        Incredibles 2   2018-06-15     118.0          PG
# 20      21          Toy Story 4   2019-06-21     100.0           G
# 21      22               Onward   2020-03-06     102.0          PG
# 22      23                 Soul   2020-12-25     100.0          PG
# 23      24                 Luca   2021-06-18     151.0         NaN
# 24      25          Turning Red   2022-03-11       NaN         NaN
# 25      26            Lightyear   2022-06-17       NaN         NaN
# 26      27                  NaN   2023-06-16     155.0   Not Rated

# %%
sql = """
        create or replace table pixar_data
        as 
        select number, film, release_date, run_time, film_rating
        from pixar_films
"""
cn.sql(sql)

# %%
cn.sql("select film, release_date, run_time, filM_rating, count(*) from pixar_data group by all order by 1 desc")
# Out:
# ┌───────────────────┬──────────────┬──────────┬─────────────┬──────────────┐
# │       film        │ release_date │ run_time │ film_rating │ count_star() │
# │      varchar      │   varchar    │  double  │   varchar   │    int64     │
# ├───────────────────┼──────────────┼──────────┼─────────────┼──────────────┤
# │ WALL-E            │ 2008-06-27   │     98.0 │ G           │            1 │
# │ Up                │ 2009-05-29   │     96.0 │ PG          │            1 │
# │ Turning Red       │ 2022-03-11   │     NULL │ NULL        │            1 │
# │ Toy Story 4       │ 2019-06-21   │    100.0 │ G           │            1 │
# │ Toy Story 3       │ 2010-06-18   │    103.0 │ G           │            1 │
# │ Toy Story 2       │ 1999-11-24   │     92.0 │ G           │            1 │
# │ Toy Story         │ 1995-11-22   │     81.0 │ G           │            1 │
# │ The Incredibles   │ 2004-11-05   │    115.0 │ PG          │            1 │
# │ The Good Dinosaur │ 2015-11-25   │     93.0 │ PG          │            1 │
# │ Soul              │ 2020-12-25   │    100.0 │ PG          │            1 │
# │  ·                │     ·        │      ·   │ ·           │            · │
# │  ·                │     ·        │      ·   │ ·           │            · │
# │  ·                │     ·        │      ·   │ ·           │            · │
# │ Incredibles 2     │ 2018-06-15   │    118.0 │ PG          │            1 │
# │ Finding Nemo      │ 2003-05-30   │    100.0 │ G           │            1 │
# │ Finding Dory      │ 2016-06-17   │     97.0 │ PG          │            1 │
# │ Coco              │ 2017-11-22   │    105.0 │ PG          │            1 │
# │ Cars 3            │ 2017-06-16   │    102.0 │ G           │            1 │
# │ Cars 2            │ 2011-06-24   │    106.0 │ G           │            1 │
# │ Cars              │ 2006-06-09   │    117.0 │ G           │            1 │
# │ Brave             │ 2012-06-22   │     93.0 │ PG          │            1 │
# │ A Bug's Life      │ 1998-11-25   │     95.0 │ G           │            1 │
# │ NULL              │ 2023-06-16   │    155.0 │ Not Rated   │            1 │
# ├───────────────────┴──────────────┴──────────┴─────────────┴──────────────┤
# │ 27 rows (20 shown)                                             5 columns │
# └──────────────────────────────────────────────────────────────────────────┘

# %%
public_response
# Out:
#                    film  rotten_tomatoes  metacritic cinema_score  \
# 0             Toy Story            100.0        95.0            A
# 1          A Bug's Life             92.0        77.0            A
# 2           Toy Story 2            100.0        88.0           A+
# 3        Monsters, Inc.             96.0        79.0           A+
# 4          Finding Nemo             99.0        90.0           A+
# 5       The Incredibles             97.0        90.0           A+
# 6                  Cars             74.0        73.0            A
# 7           Ratatouille             96.0        96.0            A
# 8                WALL-E             95.0        95.0            A
# 9                    Up             98.0        88.0           A+
# 10          Toy Story 3             98.0        92.0            A
# 11               Cars 2             40.0        57.0           A-
# 12                Brave             78.0        69.0            A
# 13  Monsters University             80.0        65.0            A
# 14           Inside Out             98.0        94.0            A
# 15    The Good Dinosaur             76.0        66.0            A
# 16         Finding Dory             94.0        77.0            A
# 17               Cars 3             69.0        59.0            A
# 18                 Coco             97.0        81.0           A+
# 19        Incredibles 2             93.0        80.0           A+
# 20          Toy Story 4             97.0        84.0            A
# 21               Onward             88.0        61.0           A-
# 22                 Soul             96.0        83.0          NaN
# 23                 Luca              NaN         NaN          NaN
#
#     critics_choice
# 0              NaN
# 1              NaN
# 2            100.0
# 3             92.0
# 4             97.0
# 5             88.0
# 6             89.0
# 7             91.0
# 8             90.0
# 9             95.0
# 10            97.0
# 11            67.0
# 12            81.0
# 13            79.0
# 14            93.0
# 15            75.0
# 16            89.0
# 17            66.0
# 18            89.0
# 19            86.0
# 20            94.0
# 21            79.0
# 22            93.0
# 23             NaN

# %%
# Which films have the highest score in each rating system?
# rotten_tomatoes
sql = """
        create or replace table response_data
        as 
        select film, rotten_tomatoes, metacritic, cinema_score, critics_choice
        from public_response
"""
cn.sql(sql)
cn.sql("select pixar.film, max(response.rotten_tomatoes) as score from pixar_data pixar join response_data response on pixar.film = response.film group by pixar.film order by max(response.rotten_tomatoes) desc limit 2")
# Out:
# ┌─────────────┬────────┐
# │    film     │ score  │
# │   varchar   │ double │
# ├─────────────┼────────┤
# │ Toy Story 2 │  100.0 │
# │ Toy Story   │  100.0 │
# └─────────────┴────────┘

# %%
cn.sql("select pixar.film, max(response.metacritic) as score from pixar_data pixar join response_data response on pixar.film = response.film group by pixar.film order by max(response.metacritic) desc limit 2")
# Out:
# ┌─────────────┬────────┐
# │    film     │ score  │
# │   varchar   │ double │
# ├─────────────┼────────┤
# │ Ratatouille │   96.0 │
# │ Toy Story   │   95.0 │
# └─────────────┴────────┘

# %%
cn.sql("select pixar.film, max(response.cinema_score) as score from pixar_data pixar join response_data response on pixar.film = response.film group by pixar.film order by max(response.cinema_score)limit 2")
# Out:
# ┌─────────────────────┬─────────┐
# │        film         │  score  │
# │       varchar       │ varchar │
# ├─────────────────────┼─────────┤
# │ Monsters University │ A       │
# │ Cars 3              │ A       │
# └─────────────────────┴─────────┘

# %%
cn.sql("select pixar.film, max(response.critics_choice) as score from pixar_data pixar join response_data response on pixar.film = response.film group by pixar.film order by max(response.critics_choice) desc limit 2")
# Out:
# ┌─────────────┬────────┐
# │    film     │ score  │
# │   varchar   │ double │
# ├─────────────┼────────┤
# │ Toy Story 2 │  100.0 │
# │ Toy Story 3 │   97.0 │
# └─────────────┴────────┘

# %%
box_office = pandas.read_csv('https://raw.githubusercontent.com/erictleung/pixarfilms/master/data-raw/box_office.csv')

# %%
box_office
# Out:
#                    film       budget  box_office_us_canada  box_office_other  \
# 0             Toy Story   30000000.0             223225679         171210907
# 1          A Bug's Life  120000000.0             162798565         200460294
# 2           Toy Story 2   90000000.0             245852179         265506097
# 3        Monsters, Inc.  115000000.0             255873250         272900000
# 4          Finding Nemo   94000000.0             339714978         531300000
# 5       The Incredibles   92000000.0             261441092         370001000
# 6                  Cars  120000000.0             244082982         217900167
# 7           Ratatouille  150000000.0             206445654         417280431
# 8                WALL-E  180000000.0             223808164         297503696
# 9                    Up  175000000.0             293004164         442094918
# 10          Toy Story 3  200000000.0             415004880         651964823
# 11               Cars 2  200000000.0             191452396         368400000
# 12                Brave  185000000.0             237283207         301700000
# 13  Monsters University  200000000.0             268492764         475066843
# 14           Inside Out  175000000.0             356461711         501149463
# 15    The Good Dinosaur  175000000.0             123087120         209120551
# 16         Finding Dory  200000000.0             486295561         542275328
# 17               Cars 3  175000000.0             152901115         231029541
# 18                 Coco  175000000.0             210460015         604181157
# 19        Incredibles 2  200000000.0             608581744         634223615
# 20          Toy Story 4  200000000.0             434038008         639356585
# 21               Onward  175000000.0              61555145          80384897
# 22                 Soul  150000000.0                946154         120957731
# 23                 Luca          NaN               1324302          49788012
# 24          Turning Red  175000000.0               1399001          20414357
# 25            Lightyear  200000000.0             118307188         108118232
# 26            Elemental  200000000.0             154426697         342017611
# 27         Inside Out 2  200000000.0             652980194        1045050771
#
#     box_office_worldwide
# 0              394436586
# 1              363258859
# 2              511358276
# 3              528773250
# 4              871014978
# 5              631442092
# 6              461983149
# 7              623726085
# 8              521311860
# 9              735099082
# 10            1066969703
# 11             559852396
# 12             538983207
# 13             743559607
# 14             857611174
# 15             332207671
# 16            1028570889
# 17             383930656
# 18             814641172
# 19            1242805359
# 20            1073394593
# 21             141940042
# 22             121903885
# 23              51112314
# 24              21813358
# 25             226425420
# 26             496444308
# 27            1698030965

# %%
# How does the box_office_us_canada value compare to the various ratings?
# Is the trend different for box_office_worldwide?
